# %%
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'
from collections import defaultdict
import warnings
warnings.filterwarnings("ignore", category=DeprecationWarning) 

import matplotlib
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import pymc as pm
import scipy as sp

import memory as my
from spikesort import catalog

# %%
database = '//Users/mat/Dropbox/Data/LLRR.sqlite'
log = catalog.open(database)
units = log.query(log.Unit).join(log.Session).\
        filter(log.Unit.cluster != 0).\
        filter(log.Unit.rate > 0.5).\
        filter(log.Session.rat != 'ALY2B').\
        all()

# This takes a long time, but it is all in loading the data from the hard drive.
# I should figure out a way to make the loading more efficient.
lkr = my.timelock.timelock(units)
lkr.lock('C in')
# Out:
# 30 sessions locked to C in

# %% [markdown]
# Okay, so here I want to build a heirarchical model for looking at the selectivity of neurons with regard to past goals, future goals, and switch trials. First, I'm going to build a model to calculate the rate difference between past goals for one neuron in one bin around `C in`.

# %%
lkr.lock('C in')
data = lkr[53].groupby(['PG outcome', 'FG outcome']).get_group((my.HIT, my.HIT))
results = {}
for goal, goal_data in data.groupby('PG port'):
    goal_rates = my.analyze.time_histogram(goal_data, limit=(-0.05, 0.05)).values
    results[goal] = goal_rates.flatten()/10.

# %%
plt.hist(results[my.RIGHT], alpha=0.3, range=(0,10), bins=10, label='Right')
plt.hist(results[my.LEFT], alpha=0.3, range=(0,10), bins=10, label='Left')
leg = plt.legend()

# %% [markdown]
# Clearly, the number of spikes in this time window is greater when the past goal was the right port. Let's see if we can build a model that finds the rate difference and matches our intuition. We will use Poisson likelihoods to model the spike counts during our time window. The priors for each Poisson rate will be exponential distributions, `rate_left` and `rate_right`. We can also sample the difference in rates between left and right trials, called `delta` in the model.

# %%
with pm.Model() as model:
    # Define priors
    rate_right = pm.Exponential('rate_right', 1)
    rate_left = pm.Exponential('rate_left', 1)
    
    delta = pm.Deterministic('delta', rate_left - rate_right)
    
    # Define likelihood
    obs_right = pm.Poisson('obs_right', rate_right, observed=results[my.RIGHT])
    obs_left = pm.Poisson('obs_left', rate_left, observed=results[my.LEFT])
    
    # Do the inference
    start = pm.find_MAP()
    step = pm.NUTS()
    trace = pm.sample(2000, step, start=start)
# Out:
#  [-----            15%                  ] 300 of 2000 complete in 0.5 sec
#  [------------     32%                  ] 658 of 2000 complete in 1.0 sec
#  [-----------------51%                  ] 1035 of 2000 complete in 1.5 sec
#  [-----------------71%-------           ] 1424 of 2000 complete in 2.0 sec
#  [-----------------90%--------------    ] 1802 of 2000 complete in 2.5 sec
#  [-----------------100%-----------------] 2000 of 2000 complete in 2.8 sec

# %%
fig = pm.traceplot(trace)

# %%
side_map = {my.LEFT:"left", my.RIGHT:"right"}
color_map = {my.LEFT:"#348ABD", my.RIGHT:"#A60628"}
for each in results:
    plt.hist(results[each], alpha=0.3, range=(0,10), bins=10, 
             label=side_map[each], align='left', color=color_map[each])
    poisson = sp.stats.poisson(trace['rate_{}'.format(side_map[each])].mean())
    plt.plot(poisson.pmf(np.arange(10))*len(results[each]), 'o', color=color_map[each])

p_selective = max((trace['delta']>=0).mean(), 
                  (trace['delta']<=0).mean())
print("Probability that rates are different: {} (Poisson Bayesian model)".format(p_selective))
U, p_mw = sp.stats.mannwhitneyu(results[my.RIGHT], results[my.LEFT])
print("Mann-Whitney test p-value: {} (Mann-Whitney U)".format(p_mw))
# Out:
# Probability that rates are different: 1.0 (Poisson Bayesian model)
# Mann-Whitney test p-value: 8.27123257273e-46 (Mann-Whitney U)

# %%
p_results = defaultdict(list)

for unit in units:
    data = lkr[unit.id].groupby(['PG outcome', 'FG outcome']).get_group((my.HIT, my.HIT))
    spikes = {}
    for goal, goal_data in data.groupby('PG port'):
        goal_rates = my.analyze.time_histogram(goal_data, limit=(-0.05, 0.05)).values
        spikes[goal] = goal_rates.flatten()/10.
    
    with pm.Model() as model:
        # Define priors

        rate_right = pm.Exponential('rate_left', 1)
        rate_left = pm.Exponential('rate_right', 1)

        delta = pm.Deterministic('delta', rate_left - rate_right)

        # Define likelihood
        obs_right = pm.Poisson('obs_right', rate_right, observed=spikes[my.RIGHT])
        obs_left = pm.Poisson('obs_left', rate_left, observed=spikes[my.LEFT])

        # Do the inference
        start = pm.find_MAP()
        step = pm.Slice()
        trace = pm.sample(2000, step, start=start, progressbar=False)
    
    p_selective = min((trace['delta'][500:]>=0).mean(), 
                  (trace['delta'][500:]<=0).mean())
    U, p_mw = sp.stats.mannwhitneyu(spikes[my.RIGHT], spikes[my.LEFT])
    
    p_results['bayes'].append(p_selective)
    p_results['mw_U'].append(p_mw)

# %%
p_crit=0.05/float(len(units))
n_bayes = np.mean(np.array(p_results['bayes']) < p_crit)
n_mw = np.mean(np.array(p_results['mw_U']) < p_crit)
print("Fraction of significant units: Bayes = {}, MW = {}".format(n_bayes, n_mw))
# Out:
# Fraction of significant units: Bayes = 0.213197969543, MW = 0.213197969543

# %% [markdown]
# So basically, we get exactly the same result using a Bayesian model, or the Mann-Whitney *U* test. The Bayesian model takes longer to calculate since I have to sample from the posterior. But, I feel that it is better philosophically.

# %% [markdown]
# Okay, this is working well for one neuron at a time. But, I want to build a heirarchical model. Let's try this out. Let's set up the data here.

# %%
lkr.lock('C in')
data = pd.DataFrame(columns=['unit', 'spikes', 'goal'])
for each in units:
    unit_data = lkr[each.id].groupby(['PG outcome', 'FG outcome']).get_group((my.HIT, my.HIT))
    spikes = my.analyze.time_histogram(unit_data, limit=(-0.05, 0.05))/10
    spikes.columns = ['spikes']
    spikes['unit'] = each.id
    spikes['goal'] = unit_data['FG port']
    data = pd.concat([data, spikes])
    
ids = tuple(each.id for each in units)
unit_idx_left = np.array([ids.index(each) for each in data[data['goal']==my.LEFT].unit])
unit_idx_right = np.array([ids.index(each) for each in data[data['goal']==my.RIGHT].unit])

# %%
N_units = len(units)

with pm.Model() as model:
    # Set hyperpriors
    alpha = pm.Exponential('alpha', 1)
    beta = pm.Exponential('beta', 1)
    #lam_right = pm.Exponential('lam_right', 1)
    
    # Set rate priors
    rate_left = pm.Gamma('rate_left', alpha, beta, shape=N_units)
    rate_right = pm.Gamma('rate_right', alpha, beta, shape=N_units)
    
    # Rate differences between left and right
    deltas = pm.Deterministic('deltas', rate_left - rate_right)
    
    # Data likelihood
    obs_left = pm.Poisson('obs_left', rate_left[unit_idx_left], observed=data[data['goal']==my.LEFT].spikes.values)
    obs_right = pm.Poisson('obs_right', rate_right[unit_idx_right], observed=data[data['goal']==my.RIGHT].spikes.values)

# %%
with model:
    # Do the inference
    start = pm.find_MAP()
    step = pm.Metropolis()
    trace = pm.sample(10000, step, start=start)
# Out:
#  [                  2%                  ] 213 of 10000 complete in 0.5 sec
#  [-                 4%                  ] 422 of 10000 complete in 1.0 sec
#  [--                6%                  ] 630 of 10000 complete in 1.5 sec
#  [---               8%                  ] 839 of 10000 complete in 2.0 sec
#  [---              10%                  ] 1048 of 10000 complete in 2.5 sec
#  [----             12%                  ] 1256 of 10000 complete in 3.0 sec
#  [-----            14%                  ] 1464 of 10000 complete in 3.5 sec
#  [------           16%                  ] 1665 of 10000 complete in 4.0 sec
#  [-------          18%                  ] 1871 of 10000 complete in 4.5 sec
#  [-------          20%                  ] 2075 of 10000 complete in 5.0 sec
#  [--------         22%                  ] 2281 of 10000 complete in 5.5 sec
#  [---------        24%                  ] 2487 of 10000 complete in 6.0 sec
# ...

# %%
with model:
    trace = pm.sample(20000, step, trace=trace)
# Out:
#  [                  0%                  ] 139 of 20000 complete in 0.5 sec
#  [                  1%                  ] 348 of 20000 complete in 1.0 sec
#  [-                 2%                  ] 557 of 20000 complete in 1.5 sec
#  [-                 3%                  ] 765 of 20000 complete in 2.0 sec
#  [-                 4%                  ] 970 of 20000 complete in 2.5 sec
#  [--                5%                  ] 1177 of 20000 complete in 3.0 sec
#  [--                6%                  ] 1384 of 20000 complete in 3.5 sec
#  [---               7%                  ] 1591 of 20000 complete in 4.0 sec
#  [---               8%                  ] 1798 of 20000 complete in 4.5 sec
#  [---              10%                  ] 2003 of 20000 complete in 5.0 sec
#  [----             11%                  ] 2207 of 20000 complete in 5.5 sec
#  [----             12%                  ] 2411 of 20000 complete in 6.0 sec
# ...

# %%
fig = pm.traceplot(trace[-20000:])

# %%
# Get the percentage of delta samples that are greater than 0
# to get the probability that the rate is different left vs right
ps = np.array([max((each>0).mean(), (each<=0).mean()) 
               for each in trace[-2000:]['deltas'].T])
np.sum(ps >= 0.95)
# Out:
# 44

# %% [markdown]
# Okay, let's try a simpler method using a conjugate prior with the Poisson likelihood to get a posterior distribution for each neuron. The conjugate prior for the Poisson rate $\lambda$ is $\mathrm{Gamma}(\alpha, \beta)$. The conjugate posterior is
#
# $$
# P\left(\lambda\bigl\vert\,\mathbf{x}\right) = \mathrm{Gamma}\left(\alpha + \sum_{i=1}^{n} x_i, \beta + n\right)
# $$
#
# But, I am really interested in the difference between the spike rates of left and right past goals. The problem here is that the difference of Gamma distributions is not easy to calculate.

# %% [markdown]
# Okay, maybe I can use my analysis for individual neurons on each neuron independently. Let's try that, but let's use the Jeffreys Prior for the Poisson rate factor $\lambda$ instead, $$p(\lambda) = \sqrt{\frac{1}{\lambda}}$$

# %%
import theano.tensor as T
data = lkr[53].groupby(['PG outcome', 'FG outcome']).get_group((my.HIT, my.HIT))
spikes = my.analyze.time_histogram(data, limit=(-0.05, 0.05))/10.
spikes.columns = ['spikes']
spikes['goal'] = data['PG port']
with pm.Model() as model:
    
    # rate parameter lambda Jeffreys' prior
    rate_left = pm.DensityDist('rate_left', lambda value: -0.5*T.log(T.abs_(value)), testval=1)
    rate_right = pm.DensityDist('rate_right', lambda value: -0.5*T.log(T.abs_(value)), testval=1)
    delta = pm.Deterministic('delta', rate_left - rate_right)
    
    # Assign rates to appropriate trials
    #rates = pm.switch(spikes.goal.values == my.LEFT, rate_left, rate_right)
    
    # Poisson likelihood
    likelihood_left = pm.Poisson('likelihood_left', rate_left, observed=spikes[spikes['goal']==my.LEFT].spikes)
    likelihood_right = pm.Poisson('likelihood_right', rate_right, observed=spikes[spikes['goal']==my.RIGHT].spikes)

# %%
with model:
    start = pm.find_MAP()
    step = pm.NUTS(scaling=start)
    trace = pm.sample(2000, step, start=start, progressbar=False)

# %%
fig = pm.traceplot(trace)

# %%
fig, ax = plt.subplots()
goals = spikes.groupby(['goal'])
for goal, goal_data in goals:
    _ = ax.hist(goal_data['spikes'].values, range=(0,10), bins=10, align='left', 
                label={my.LEFT:'left', my.RIGHT:'right'}[goal], 
                color={my.LEFT:'r', my.RIGHT:'b'}[goal],
                alpha=0.3)
poisson = sp.stats.poisson(trace['rate_left'].mean())
plt.plot(poisson.pmf(np.arange(10))*goals.count().ix[my.LEFT].values, 'or')
poisson = sp.stats.poisson(trace['rate_right'].mean())
plt.plot(poisson.pmf(np.arange(10))*goals.count().ix[my.RIGHT].values, 'ob')
p_selective = max((trace['delta'][500:]>0).mean(), 
                  (trace['delta'][500:]<=0).mean())
leg = ax.legend()

# %% [markdown]
# Poisson regression
# ------------------
#
# Now, I will try Poisson regression to capture past goal, future goal, and switch selectivity.

# %%
lkr.lock('C out')
unit = 317
data = lkr[unit].groupby(['PG outcome', 'FG outcome']).get_group((my.HIT, my.HIT))
data['switch'] = ~(data['PG port'] == data['FG port'])+1

spikes = my.analyze.time_histogram(data, limit=(-0.05, 0.05), bin_width=0.1)*0.1
predictors = data[['PG port', 'FG port', 'switch']]-1
predictors['const'] = 1. # Include the intercept

# %%
import theano.tensor as t
with pm.Model() as poisson_model:
    # priors for coefficients
    coeffs = pm.Normal('coeffs', 0, sd=1, shape=(1, predictors.shape[1]))
    
    p = t.exp(pm.sum(coeffs*predictors.values, 1))
    
    obs = pm.Poisson('obs', p, observed=spikes.values.ravel())

# %%
with poisson_model:
    start = pm.find_MAP()
    step = pm.NUTS()
    poisson_trace = pm.sample(2000, step, start=start)
# Out:
#  [----             12%                  ] 253 of 2000 complete in 0.5 sec
#  [----------       27%                  ] 550 of 2000 complete in 1.0 sec
#  [---------------- 43%                  ] 863 of 2000 complete in 1.5 sec
#  [-----------------60%---               ] 1212 of 2000 complete in 2.0 sec
#  [-----------------76%---------         ] 1537 of 2000 complete in 2.5 sec
#  [-----------------93%---------------   ] 1862 of 2000 complete in 3.0 sec
#  [-----------------100%-----------------] 2000 of 2000 complete in 3.2 sec

# %%
fig = pm.traceplot(poisson_trace)

# %% [markdown]
# We can compare the Poisson regression model to a linear (Normal) regression model.

# %%
with pm.Model() as linear_model:
    # priors for coefficients
    coeffs = pm.Normal('coeffs', 0, sd=1, shape=(1, predictors.shape[1]))
    sigma = pm.Uniform('sigma', 0, 10)
    
    p = pm.sum(coeffs*predictors.values, 1)
    
    obs = pm.Normal('obs', mu=p, sd=sigma, observed=spikes.values.ravel())

# %%
with linear_model:
    start = pm.find_MAP()
    step = pm.NUTS()
    linear_trace = pm.sample(2000, step, start=start)
# Out:
#  [--                7%                  ] 145 of 2000 complete in 0.5 sec
#  [------           16%                  ] 320 of 2000 complete in 1.0 sec
#  [---------        25%                  ] 502 of 2000 complete in 1.5 sec
#  [-------------    35%                  ] 704 of 2000 complete in 2.0 sec
#  [-----------------45%                  ] 905 of 2000 complete in 2.5 sec
#  [-----------------54%                  ] 1097 of 2000 complete in 3.0 sec
#  [-----------------64%----              ] 1293 of 2000 complete in 3.5 sec
#  [-----------------74%--------          ] 1488 of 2000 complete in 4.0 sec
#  [-----------------84%------------      ] 1690 of 2000 complete in 4.5 sec
#  [-----------------94%---------------   ] 1887 of 2000 complete in 5.0 sec
#  [-----------------100%-----------------] 2000 of 2000 complete in 5.3 sec

# %%
fig = pm.traceplot(trace)

# %% [markdown]
# We get similar results using the two models. But, which one is better? We should calculate the RMSE (root mean squared error) for the two models.

# %% [markdown]
# Okay, let's try a heirarchical Poisson model.

# %%
# Let's put all the data into one DataFrame

lkr.lock('C out')
data = pd.DataFrame(columns=['unit', 'spikes', 'pg', 'fg', 'sw'])
for each in units:
    unit_data = lkr[each.id].groupby(['PG outcome', 'FG outcome']).get_group((my.HIT, my.HIT))
    spikes = my.analyze.time_histogram(unit_data, limit=(-0.05, 0.05))*0.1
    spikes.columns = ['spikes']
    spikes['unit'] = each.id
    spikes['pg'] = unit_data['PG port'] - 1
    spikes['fg'] = unit_data['FG port'] - 1
    spikes['sw'] = (~(unit_data['PG port'] == unit_data['FG port'])).astype(int)
    data = pd.concat([data, spikes])
    
data['const'] = 1.
ids = tuple(each.id for each in units)
unit_idx = np.array([ids.index(each) for each in data.unit])

# %%
data.head(10)
# Out:
#     fg  pg  spikes  sw  unit  const
# 1    1   1       0   0    36      1
# 2    0   1       0   1    36      1
# 3    0   0       0   0    36      1
# 4    1   0       0   1    36      1
# 5    1   1       0   0    36      1
# 6    0   1       0   1    36      1
# 7    0   0       0   0    36      1
# 8    1   0       0   1    36      1
# 9    1   1       1   0    36      1
# 10   0   1       0   1    36      1

# %%
import theano.tensor as t

# %%
predictors = data[['pg', 'fg', 'sw', 'const']]
n_units = len(units)

with pm.Model() as model:
    # define hyperpriors
    mu = pm.Normal('mu', 0, sd=1) #, shape=(n_units,1))
    sigma = pm.Uniform('sigma', 0.05, 10)
    
    effects = pm.Normal('effects', mu=mu, sd=sigma, shape=(n_units, predictors.shape[1]))
    
    p = t.exp(pm.sum(effects[unit_idx]*predictors, 1))
    
    o = pm.Poisson('obs', p, observed=data.spikes.values)

# %%
with model:
    start = pm.find_MAP()
    step = pm.NUTS(scaling=start)
    trace = pm.sample(2000, step, start=start)
# Out:
#  [                  0%                  ] 5 of 2000 complete in 0.9 sec
#  [                  0%                  ] 7 of 2000 complete in 4.6 sec
#  [                  0%                  ] 9 of 2000 complete in 12.0 sec
#  [                  0%                  ] 10 of 2000 complete in 15.4 sec
#  [                  0%                  ] 12 of 2000 complete in 22.8 sec
#  [                  0%                  ] 13 of 2000 complete in 24.5 sec
#  [                  0%                  ] 15 of 2000 complete in 31.4 sec
#  [                  0%                  ] 16 of 2000 complete in 33.1 sec
#  [                  0%                  ] 18 of 2000 complete in 40.0 sec
#  [                  0%                  ] 19 of 2000 complete in 41.7 sec
#  [                  1%                  ] 21 of 2000 complete in 45.2 sec
#  [                  1%                  ] 22 of 2000 complete in 46.9 sec
#  [                  1%                  ] 24 of 2000 complete in 53.9 sec
# ...

# %%
with model:
    trace = pm.sample(2000, [step1, step2], trace=trace)
# Out:
#  [                  0%                  ] 8 of 2000 complete in 0.5 sec
#  [                  0%                  ] 13 of 2000 complete in 1.6 sec
#  [                  1%                  ] 20 of 2000 complete in 2.1 sec
#  [                  1%                  ] 26 of 2000 complete in 2.6 sec
#  [                  1%                  ] 28 of 2000 complete in 3.2 sec
#  [                  1%                  ] 33 of 2000 complete in 3.7 sec
#  [                  2%                  ] 41 of 2000 complete in 4.2 sec
#  [                  2%                  ] 46 of 2000 complete in 5.5 sec
#  [-                 2%                  ] 55 of 2000 complete in 6.0 sec
#  [-                 2%                  ] 58 of 2000 complete in 6.6 sec
#  [-                 3%                  ] 62 of 2000 complete in 7.1 sec
#  [-                 3%                  ] 69 of 2000 complete in 7.6 sec
#  [-                 3%                  ] 77 of 2000 complete in 8.8 sec
# ...

# %%
fig = pm.traceplot(trace)

# %%
plt.plot(trace['effects'][500:,13,2])
