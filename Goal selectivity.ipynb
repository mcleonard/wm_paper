# %%
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'
from collections import defaultdict
import warnings
warnings.filterwarnings("ignore", category=DeprecationWarning) 

import matplotlib
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import pymc as pm
import scipy as sp

import memory as my
from spikesort import catalog

# %%
database = '//Users/mat/Dropbox/Data/LLRR.sqlite'
log = catalog.open(database)
units = log.query(log.Unit).join(log.Session).\
        filter(log.Unit.cluster != 0).\
        filter(log.Unit.rate > 0.5).\
        filter(log.Session.rat != 'ALY2B').\
        all()
# Unfortunately, timelocking the data takes a long time.
# I found that loading the data into memory is what times the most time.
lkr = my.timelock.timelock(units)
lkr.lock('onset')
# Out:
# 30 sessions locked to onset

# %% [markdown]
# Okay, so here I want to build a heirarchical model for looking at the selectivity of neurons with regard to past goals, future goals, and switch trials. First, I'm going to build a model to calculate the rate difference between past goals for one neuron in one bin around `C in`.

# %%
lkr.lock('C in')
# Out:
# 30 sessions locked to C in

# %%
data = lkr[62]
results = {}
spikes = my.analyze.time_histogram(data, limit=(-0.05, 0.05))/10.
for goal, goal_data in data.groupby('PG port'):
    results[goal] = my.analyze.time_histogram(goal_data, limit=(-0.05, 0.05)).values.T.flatten()/10

# %%
spikes.columns = ['spikes']
spikes['unit'] = 62
spikes['goal'] = data['PG port']

# %%
plt.hist(results[my.RIGHT], alpha=0.3, range=(0,10), bins=10, label='Right')
plt.hist(results[my.LEFT], alpha=0.3, range=(0,10), bins=10, label='Left')
leg = plt.legend()

# %% [markdown]
# Clearly, the number of spikes in this time window is greater when the past goal was the right port. Let's see if we can build a model that finds the rate difference and matches our intuition.

# %%
n_right, n_left = len(results[my.RIGHT]), len(results[my.LEFT])
goals = np.zeros(n_right+n_left)
goals[:n_right] = my.RIGHT
goals[n_right:] = my.LEFT
observed = goals.copy()
observed[:n_right] = results[my.RIGHT]
observed[n_right:] = results[my.LEFT]
with pm.Model() as model:
    # Define priors
    left = pm.Exponential('left_rate', 3)
    right = pm.Exponential('right_rate', 3)
    
    delta = pm.Deterministic('delta', left-right)
    
    rates = pm.switch(goals==my.LEFT, left, right)
    
    # Define likelihood
    likelihood = pm.Poisson('likelihood', rates, observed=observed)
    
    # Do the inference
    start = pm.find_MAP()
    step = pm.NUTS()
    trace = pm.sample(3000, step, start=start)
# Out:
#  [----             12%                  ] 381 of 3000 complete in 0.5 sec
#  [----------       27%                  ] 824 of 3000 complete in 1.0 sec
#  [---------------- 42%                  ] 1268 of 3000 complete in 1.5 sec
#  [-----------------57%-                 ] 1725 of 3000 complete in 2.0 sec
#  [-----------------72%-------           ] 2161 of 3000 complete in 2.5 sec
#  [-----------------86%-------------     ] 2607 of 3000 complete in 3.0 sec
#  [-----------------100%-----------------] 3000 of 3000 complete in 3.4 sec

# %%
fig = pm.traceplot(trace)

# %%
plt.hist(results[my.RIGHT], alpha=0.3, range=(0,10), bins=10, label='Right', align='left')
plt.hist(results[my.LEFT], alpha=0.3, range=(0,10), bins=10, label='Left', align='left')
for each in (2.5, 97.5):
    plt.plot([np.percentile(trace['right_rate'], each)]*2,plt.ylim(), '--k')
    plt.plot([np.percentile(trace['left_rate'], each)]*2,plt.ylim(), '--k')
leg = plt.legend()
poisson = sp.stats.poisson(trace['left_rate'].mean())
plt.plot(poisson.pmf(np.arange(10))*n_left)
poisson = sp.stats.poisson(trace['right_rate'].mean())
plt.plot(poisson.pmf(np.arange(10))*n_right)
p_selective = max((trace['delta'][500:]>0).mean(), 
                  (trace['delta'][500:]<=0).mean())
print(p_selective)
# Out:
# 1.0

# %% [markdown]
# Okay, this is working well for one neuron at a time. But, I want to build a heirarchical model. Let's try this out.

# %% [markdown]
# Let's set up the data here.

# %%
from collections import defaultdict
data = pd.DataFrame(columns=['unit', 'spikes', 'goal'])
for each in units:
    unit_data = lkr[each.id]
    spikes = my.analyze.time_histogram(lkr[each.id], limit=(-0.05, 0.05))/10
    spikes.columns = ['spikes']
    spikes['unit'] = each.id
    spikes['goal'] = unit_data['FG port']
    data = pd.concat([data, spikes])
    
ids = tuple(each.id for each in units)
unit_idx = np.array([ids.index(each) for each in data.unit])

# %%
N_units = len(units)

with pm.Model() as model:
    # Set hyperpriors
    #lam = pm.Exponential('lam', 3)
    #lam_right = pm.Exponential('lam_right', 3)
    
    # Set rate priors
    rate_left = pm.Exponential('rate_left', 3, shape=N_units)
    rate_right = pm.Exponential('rate_right', 3, shape=N_units)
    
    deltas = pm.Deterministic('deltas', rate_left - rate_right)
    
    rate = pm.switch(data.goal.values == my.LEFT, rate_left[unit_idx], rate_right[unit_idx])
    
    likelihood = pm.Poisson('likelihood', rate, observed=data.spikes.values)

# %%
with model:
    # Do the inference
    start = pm.find_MAP()
    step = pm.Metropolis()
    trace = pm.sample(30000, step, start=start)
# Out:
#  [                  0%                  ] 130 of 30000 complete in 0.5 sec
#  [                  0%                  ] 264 of 30000 complete in 1.0 sec
#  [                  1%                  ] 397 of 30000 complete in 1.5 sec
#  [                  1%                  ] 528 of 30000 complete in 2.0 sec
#  [                  2%                  ] 661 of 30000 complete in 2.5 sec
#  [-                 2%                  ] 791 of 30000 complete in 3.0 sec
#  [-                 3%                  ] 919 of 30000 complete in 3.5 sec
#  [-                 3%                  ] 1049 of 30000 complete in 4.0 sec
#  [-                 3%                  ] 1179 of 30000 complete in 4.5 sec
#  [-                 4%                  ] 1307 of 30000 complete in 5.0 sec
#  [-                 4%                  ] 1440 of 30000 complete in 5.5 sec
#  [-                 5%                  ] 1573 of 30000 complete in 6.0 sec
#  [--                5%                  ] 1705 of 30000 complete in 6.5 sec
#  [--                6%                  ] 1835 of 30000 complete in 7.0 sec
#  [--                6%                  ] 1969 of 30000 complete in 7.5 sec
#  [--                6%                  ] 2097 of 30000 complete in 8.0 sec
#  [--                7%                  ] 2231 of 30000 complete in 8.5 sec
#  [-----------------76%--------          ] 15228 of 20000 complete in 57.2 sec
#  [-----------------76%---------         ] 15362 of 20000 complete in 57.7 sec
#  [-----------------77%---------         ] 15497 of 20000 complete in 58.2 sec
#  [-----------------78%---------         ] 15632 of 20000 complete in 58.7 sec
#  [-----------------78%---------         ] 15767 of 20000 complete in 59.2 sec
#  [-----------------79%----------        ] 15902 of 20000 complete in 59.7 sec
#  [-----------------80%----------        ] 16036 of 20000 complete in 60.2 sec
#  [-----------------80%----------        ] 16171 of 20000 complete in 60.7 sec
#  [-----------------81%----------        ] 16306 of 20000 complete in 61.2 sec
#  [-----------------82%-----------       ] 16441 of 20000 complete in 61.7 sec
#  [-----------------82%-----------       ] 16569 of 20000 complete in 62.2 sec
#  [-----------------83%-----------       ] 16704 of 20000 complete in 62.7 sec
#  [-----------------84%-----------       ] 16838 of 20000 complete in 63.3 sec
#  [-----------------84%------------      ] 16973 of 20000 complete in 63.8 sec
#  [-----------------85%------------      ] 17108 of 20000 complete in 64.3 sec
#  [-----------------86%------------      ] 17243 of 20000 complete in 64.8 sec
#  [-----------------86%-------------     ] 17377 of 20000 complete in 65.3 sec
#  [-----------------87%-------------     ] 17512 of 20000 complete in 65.8 sec
#  [-----------------88%-------------     ] 17646 of 20000 complete in 66.3 sec
#  [-----------------88%-------------     ] 17780 of 20000 complete in 66.8 sec
#  [-----------------89%--------------    ] 17915 of 20000 complete in 67.3 sec
#  [-----------------90%--------------    ] 18050 of 20000 complete in 67.8 sec
#  [-----------------90%--------------    ] 18185 of 20000 complete in 68.3 sec
#  [-----------------91%--------------    ] 18320 of 20000 complete in 68.8 sec
#  [-----------------92%---------------   ] 18455 of 20000 complete in 69.3 sec
#  [-----------------92%---------------   ] 18590 of 20000 complete in 69.8 sec
#  [-----------------93%---------------   ] 18725 of 20000 complete in 70.3 sec
#  [-----------------94%---------------   ] 18860 of 20000 complete in 70.8 sec
#  [-----------------94%----------------  ] 18994 of 20000 complete in 71.3 sec
#  [-----------------95%----------------  ] 19129 of 20000 complete in 71.8 sec
#  [-----------------96%----------------  ] 19263 of 20000 complete in 72.3 sec
#  [-----------------96%----------------  ] 19397 of 20000 complete in 72.8 sec
#  [-----------------97%----------------- ] 19530 of 20000 complete in 73.3 sec
#  [-----------------98%----------------- ] 19664 of 20000 complete in 73.8 sec
#  [-----------------98%----------------- ] 19798 of 20000 complete in 74.3 sec
#  [-----------------99%----------------- ] 19932 of 20000 complete in 74.8 sec
#  [-----------------100%-----------------] 20000 of 20000 complete in 75.1 sec

# %%
fig = pm.traceplot(trace[20000:])

# %%
# Get the percentage of delta samples that are greater than 0
# to get the probability that the rate is different left vs right
ps = np.array([max((each>0).mean(), (each<=0).mean()) 
               for each in trace[20000:]['deltas'].T])

# %%
np.sum(ps >= 0.99)
# Out:
# 56
